# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Documents\15 days project datasets\Flipkart Mobile - 2.csv")
df
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# ...

# %%
df['brand'].unique()
# Out:
# array(['Apple', 'Poco', 'Realme', 'Samsung', 'Xiaomi'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             430 non-null    object
#  1   model             430 non-null    object
#  2   base_color        430 non-null    object
#  3   processor         430 non-null    object
#  4   screen_size       430 non-null    object
#  5   ROM               430 non-null    int64
#  6   RAM               430 non-null    int64
#  7   display_size      430 non-null    float64
#  8   num_rear_camera   430 non-null    int64
#  9   num_front_camera  430 non-null    int64
#  10  battery_capacity  430 non-null    int64
#  11  ratings           430 non-null    float64
#  12  num_of_ratings    430 non-null    int64
#  13  sales_price       430 non-null    int64
#  14  discount_percent  430 non-null    float64
#  15  sales             430 non-null    float64
# ...

# %%
df.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.320930      6.369767         2.904651
# std     63.164064    2.182635      0.369549         0.952350
# min      8.000000    1.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    4.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    23567.944186
# std            0.227280        986.907252    0.151494    56096.277784
# min            1.000000       1800.000000    3.000000        4.000000
# ...

# %%
df[df['sales']==df['sales'].max()]
# Out:
#       brand         model base_color processor screen_size  ROM  RAM  \
# 395  Xiaomi  Redmi Note 4       Gold  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 395           5.5                1                 1              4100
#
#      ratings  num_of_ratings  sales_price  discount_percent   sales
# 395      4.4          642373         8565              0.04  550.19

# %% [markdown]
# ##### The product with the highest sales in the Flipkart dataset is the Xiaomi Note 4

# %%
sns.distplot(df['sales_price'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2852\1153413794.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sales_price'])
# <Axes: xlabel='sales_price', ylabel='Density'>

# %% [markdown]
# ##### This skewed distribution suggests that the majority of products are relatively affordable, with fewer products at higher price points.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='discount_percent', y='sales', data=df)
plt.title('Impact of Discounts on Sales')
plt.xlabel('Discount Percentage')
plt.ylabel('Sales')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
#  - As the discount percentage increases, sales tend to decrease
#  - The majority of sales occur at lower discount percentages
#    - moderate discounts appear to be most effective for driving mobile sales on Flipkart.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['ratings'], bins=5, kde=False, color='skyblue')
plt.title('Distribution of Product Ratings')
plt.xlabel('Product Ratings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### The majority of product ratings fall within the higher rating range, indicating that customers are generally satisfied with their purchases

# %%
high_rated_mobiles = df[df['ratings']==df['ratings'].max()]
print("Products with the Highest Ratings:")
print(high_rated_mobiles[['brand', 'model', 'ratings']])
# Out:
# Products with the Highest Ratings:
#        brand       model  ratings
# 3      Apple   iPhone XR      4.6
# 4      Apple   iPhone 12      4.6
# 5      Apple   iPhone 12      4.6
# 6      Apple   iPhone 12      4.6
# 7      Apple   iPhone 12      4.6
# 8      Apple   iPhone 12      4.6
# 9      Apple   iPhone 12      4.6
# 11     Apple   iPhone 12      4.6
# 13     Apple   iPhone 12      4.6
# 15     Apple   iPhone XR      4.6
# 16     Apple   iPhone 12      4.6
# 17     Apple   iPhone 12      4.6
# 19     Apple   iPhone 12      4.6
# 21     Apple   iPhone XR      4.6
# 22     Apple   iPhone 12      4.6
# 23     Apple   iPhone 12      4.6
# 24     Apple   iPhone XR      4.6
# 25     Apple   iPhone XR      4.6
# 26     Apple   iPhone 12      4.6
# 27     Apple   iPhone XR      4.6
# 29     Apple   iPhone XR      4.6
# 33     Apple   iPhone XR      4.6
# 41     Apple   iPhone 12      4.6
# 44     Apple   iPhone XR      4.6
# 45     Apple   iPhone XR      4.6
# ...

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='brand', data=high_rated_mobiles, palette='viridis')
plt.title('Distribution of Products with Highest Ratings')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - The products with the highest ratings (4.6) include several models from Apple, such as iPhone XR, iPhone 12

# %%
low_rated_mobiles = df[df['ratings'] == df['ratings'].min()]
print("Products with the Lowest Ratings:")
print(low_rated_mobiles[['brand', 'model', 'ratings']])
# Out:
# Products with the Lowest Ratings:
#        brand          model  ratings
# 328  Samsung  Galaxy Fold 2      3.0

# %% [markdown]
# - The product with the lowest rating in the dataset is the Samsung Galaxy Fold 2, which has a rating of 3.0

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='brand', y='discount_percent', data=df, palette='rainbow')
plt.title('Distribution of Discount Percentages Across Brands')
plt.xlabel('Brand')
plt.ylabel('Discount Percentage')
plt.show()

# %% [markdown]
# - Apple has the lowest discount range.
# - Poco, Realme, and Samsung have similar median discount percentages but vary in their ranges.
#    - Xiaomi stands out with its diverse discount offerings, while Apple remains conservative in its discounts

# %%
plt.figure(figsize=(14, 6))
sns.barplot(x='RAM', y='sales', data=df, palette='Set1')
plt.title('Relationship between RAM and Sales')
plt.xlabel('RAM')
plt.ylabel('Sales')
plt.show()

plt.figure(figsize=(14, 6))
sns.barrplot(x='ROM', y='sales', data=df, palette='Set2')
plt.title('Relationship between ROM and Sales')
plt.xlabel('ROM')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# - Phones with 2GB RAM have the highest sales percentage, nearly reaching 100
# - Other RAM sizes (3GB, 4GB, 6GB, 8GB, 12GB) show significantly lower sales percentages
# - Phones with 16GB ROM have the highest sales percentage.
# - There’s a significant drop in sales after 16GB ROM.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='ratings', y='sales', data=df, palette='viridis')
plt.title('Relationship between Ratings and Sales')
plt.xlabel('Ratings')
plt.ylabel('Sales')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2852\1430001071.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='ratings', y='sales', data=df, palette='viridis')

# %% [markdown]
# - Products with ratings around 4 and above show a positive correlation with sales.
# - As ratings increase, there is a noticeable upward trend in sales.
# - The left-skewed pattern indicates that products with lower ratings have varying sales, while higher ratings are consistently associated with higher sales
